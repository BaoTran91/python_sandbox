# %% [markdown]
# ### PROCESS MANAGEMENT

# %% [markdown]
# Stack: The Stack stores temporary data like function parameters, returns addresses, and local variables.
# Heap Allocates memory, which may be processed during its run time.
# Data: It contains the variable.
# Text: Text Section includes the current activity, which is represented by the value of the Program Counter.

# %% [markdown]
# ![122319_0638_ProcessMana2.png](attachment:122319_0638_ProcessMana2.png)

# %% [markdown]
# New: The new process is created when a specific program calls from secondary memory/ hard disk to primary memory/ RAM a
# Ready: In a ready state, the process should be loaded into the primary memory, which is ready for execution.
# Waiting: The process is waiting for the allocation of CPU time and other resources for execution.
# Executing: The process is an execution state.
# Blocked: It is a time interval when a process is waiting for an event like I/O operations to complete.
# Suspended: Suspended state defines the time when a process is ready for execution but has not been placed in the ready queue.
# Terminated: Terminated state specifies the time when a process is terminated

# %% [markdown]
# Spinlock - loop again and test lock
# Used when process should not be put to sleep like Interrupt service routines.
# Use when lock will be granted in reasonably short time.
# Processor is busy doing nothing till lock is granted, wasting CPU cycles.
#
# Mutex - wait queue (blocked) - context switching -> save state of blocked process and load in running process
# Used when putting process is not harmful like user space programs.
# Use when there will be considerable time before process gets the lock.
# Incur process context switch and scheduling cost.
#
# Semaphores - wait (-1) signal (+1) - block when count goes negative

# %% [markdown]
# deadlock is a state in which each member of a group of actions, is waiting for some other member to release a lock
# livelock is similar to a deadlock, except that the states of the processes involved in the livelock constantly change with regard to one another, none progressing. Livelock is a risk with some algorithms that detect and recover from deadlock
# -> Try to avoid using multiple locks.
# -> request locks in a strict ordering

# %% [markdown]
# Kernel - handles startup = i/o from other programs = manage memory and hardware peripherals
# A computer program makes a system call when it makes a request to the operating system's kernel.

# %% [markdown]
# ![1_aJZQxhEaoRC_T_MOpngilg.png](attachment:1_aJZQxhEaoRC_T_MOpngilg.png)
