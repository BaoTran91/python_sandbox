# %% [markdown]
# ## Algorithm Analysis

# %%
import time

def sumOfN(n):
   start = time.time()

   theSum = 0
   for i in range(1,n+1):
      theSum = theSum + i

   end = time.time()

   return theSum,end-start

def sumOfN2(n):
   start = time.time()

   theSum = 0
   for i in range(1,n+1):
        n = i
        theSum = theSum + n

   end = time.time()

   return theSum,end-start

def sumOfN3(n):
    start = time.time()
    theSum=(n*(n+1))/2
    end = time.time()
    return theSum,end-start

# %%
for i in range(5):
    print("Sum is %d required %10.7f seconds"%sumOfN(10000*i))
print("--")
for i in range(5):
    print("Sum is %d required %10.7f seconds"%sumOfN2(10000*i))
print("--")
for i in range(5):
    print("Sum is %d required %10.7f seconds"%sumOfN3(10000*i))
# Out:
# Sum is 0 required  0.0000019 seconds
# Sum is 50005000 required  0.0010839 seconds
# Sum is 200010000 required  0.0018799 seconds
# Sum is 450015000 required  0.0036581 seconds
# Sum is 800020000 required  0.0044019 seconds
# --
# Sum is 0 required  0.0000007 seconds
# Sum is 50005000 required  0.0012162 seconds
# Sum is 200010000 required  0.0025301 seconds
# Sum is 450015000 required  0.0034609 seconds
# Sum is 800020000 required  0.0039051 seconds
# --
# Sum is 0 required  0.0000010 seconds
# Sum is 50005000 required  0.0000012 seconds
# Sum is 200010000 required  0.0000010 seconds
# Sum is 450015000 required  0.0000000 seconds
# Sum is 800020000 required  0.0000012 seconds

# %% [markdown]
# ![Screen%20Shot%202021-03-30%20at%202.23.59%20AM.png](attachment:Screen%20Shot%202021-03-30%20at%202.23.59%20AM.png)

# %% [markdown]
# ![Screen%20Shot%202021-03-30%20at%202.24.49%20AM.png](attachment:Screen%20Shot%202021-03-30%20at%202.24.49%20AM.png)

# %%
b=6
c=10
for i in range(n):
   for j in range(n):
      x = i * i
      y = j * j
      z = i * j
for k in range(n):
   w = a*k + 45
   v = b*b
d = 33

# %%
The number of assignment operations is the sum of four terms. 
The first term is the constant 3, representing the three assignment 
statements at the start of the fragment. The second term is 3𝑛2, 
since there are three statements that are performed 𝑛2 times 
due to the nested iteration. The third term is 2𝑛, two statements 
iterated n times. Finally, the fourth term is the constant 1, 
representing the final assignment statement. 
This gives us 𝑇(𝑛)=3+3𝑛2+2𝑛+1=3𝑛2+2𝑛+4. By looking at the exponents, 
we can easily see that the 𝑛2 term will be dominant and therefore 
this fragment of code is 𝑂(𝑛2). Note that all of the other terms as 
well as the coefficient on the dominant term can be ignored as n grows 
larger.

# %% [markdown]
# ## An Anagram Detection Example

# %%
def anagramSolution1(s1,s2): #Checking Off
    start = time.time()
    stillOK = True
    if len(s1) != len(s2): #CHECK LENGTH
        stillOK = False

    alist = list(s2)       #Convert string to list
    pos1 = 0

    while pos1 < len(s1) and stillOK: #CHECK EACH LETTER AND POP WHEN FOUND
        pos2 = 0
        found = False
        while pos2 < len(alist) and not found:
            if s1[pos1] == alist[pos2]:
                found = True
            else:
                pos2 = pos2 + 1

        if found:
            alist[pos2] = None
        else:
            stillOK = False

        pos1 = pos1 + 1
    end = time.time()

    return stillOK,end-start

# %% [markdown]
# ![Screen%20Shot%202021-03-30%20at%202.48.39%20AM.png](attachment:Screen%20Shot%202021-03-30%20at%202.48.39%20AM.png)

# %%
def anagramSolution2(s1,s2): #Sort and Compare
    start = time.time()
    alist1 = list(s1)
    alist2 = list(s2)

    alist1.sort()
    alist2.sort()

    pos = 0
    matches = True

    while pos < len(s1) and matches:
        if alist1[pos]==alist2[pos]:
            pos = pos + 1
        else:
            matches = False
    end = time.time()
    return matches,end-start

# %% [markdown]
# At first glance you may be tempted to think that this algorithm is 𝑂(𝑛), since there is one simple iteration to compare the n characters after the sorting process. However, the two calls to the Python sort method are not without their own cost. As we will see in a later chapter, sorting is typically either 𝑂(𝑛2) or 𝑂(𝑛log𝑛), so the sorting operations dominate the iteration. In the end, this algorithm will have the same order of magnitude as that of the sorting process.

# %%
def anagramSolution4(s1,s2): #Count and Compare
    start = time.time()
    c1 = [0]*26
    c2 = [0]*26

    for i in range(len(s1)):
        pos = ord(s1[i])-ord('a')
        c1[pos] = c1[pos] + 1

    for i in range(len(s2)):
        pos = ord(s2[i])-ord('a')
        c2[pos] = c2[pos] + 1

    j = 0
    stillOK = True
    while j<26 and stillOK:
        if c1[j]==c2[j]:
            j = j + 1
        else:
            stillOK = False
    end = time.time()
    return stillOK,end-start

# %% [markdown]
# Again, the solution has a number of iterations. However, unlike the first solution, none of them are nested. The first two iterations used to count the characters are both based on n. The third iteration, comparing the two lists of counts, always takes 26 steps since there are 26 possible characters in the strings. Adding it all up gives us 𝑇(𝑛)=2𝑛+26 steps. That is 𝑂(𝑛). We have found a linear order of magnitude algorithm for solving this problem.
#
# Before leaving this example, we need to say something about space requirements. Although the last solution was able to run in linear time, it could only do so by using additional storage to keep the two lists of character counts. In other words, this algorithm sacrificed space in order to gain time.

# %%
list1 = ['abcdellllooooookkkkkkppppppoo','slkfjlskjflksjfklslkjfslkjflksjfklsjf','slkfjlskjflksjfklslkjfslkjflksjfklsjfsjkhfjkshfkhskjfhksjhfkjsfksjskjfhksjh']
list2 = ['edcbaooooooookkkkkkppppppllll','fslkfjlskjflksjfklslkjfslkjflksjfklsj','hslkfjlskjflksjfklslkjfslkjflksjfklsjfsjkhfjkshfkhskjfhksjhfkjsfksjskjfhksj']
for i in range(3):
    print(anagramSolution1(list1[i],list1[i]))
print("---")
for i in range(3):
    print(anagramSolution2(list1[i],list1[i]))
print("---")
for i in range(3):
    print(anagramSolution4(list1[i],list1[i]))
# Out:
# (True, 0.00013780593872070312)
# (True, 0.0002090930938720703)
# (True, 0.0009632110595703125)
# ---
# (True, 2.002716064453125e-05)
# (True, 1.6927719116210938e-05)
# (True, 6.127357482910156e-05)
# ---
# (True, 2.6226043701171875e-05)
# (True, 5.984306335449219e-05)
# (True, 0.0001087188720703125)
